# %% [raw]
# 1. Why are functions advantageous to have in your programs?
#
# :-Function Are Advantageous to have in our program because it reduce duplicate code and makes program shorter and easier to read.
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# :-The Code In Function Run By Calling the function whenever it's needed.
#
# 3. What statement creates a function?
#
# :-To create Function in python
#     1.Use the Keyword to def the Function
#     2.Give the Funtion Name round brackets and semi colon
#     3.write any line of code you wish to write
#     4.return the keyword at the end of function to return the output
#
# 4. What is the difference between a function and a function call?
#
# :-
# 1.A Function:- Is a block of code that does a particular operation and returns a result usually accepts inputs as parameters and returns a result.
#
# Ex. def <Function Name>(Parameters):
#         <Statements>
#
# 2.A Function Call:- To call Function you Need function name And Arguments closed In round Brackets Its Usually a bulit in function .If You Don't Have Any Arguments But Still You Need To have parenthesis
#
# Ex. print("Hello") It's A Bulit in Function
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# :-There are only one global scope per execuation of code and there are four local scope in python local scope ,global Scope,Built-In Scope, Enclosing Scope
#
# For Ex:- var=10  #Global Scope
#          def test():
#              x=1        #Enclosed Scope
#              def test1():
#                   x=2     #local Scope
#
#
# 6. What happens to variables in a local scope when the function call returns?
#
# :-It Will Return The Value.
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# :-Return Value is value in function return in script when task is complete. yes it is possible to return value multiple times from a function.
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# :-If a function does not have return statement it will return Non or undefined
#
#
# 9. How do you make a function variable refer to the global variable?
#
# :-Function Variable refer to the global variable when it is def before the function
#
# Ex:-"x=Good Boy's" #Global Function Variable
#
#     def func1():
#         print("Anup and his Friends are ",x)
#
#     func1()
#
#
#     Output:-Anup and his Friends are Good Boys
#
#
# 10. What is the data type of None?
#
# :- def test():
#         print("Good Boys")
#
#      test():
#
#
#    output:-Good Boys
#
#    x=Good Boys
#
#    "Anup"+x
#
#    It will Show Error that it can only concanate only str type and not the None type or undefined
#    And when we use return the value we can concanete the the to str.
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# :-It's not the python Module
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# :-spam.bacon()
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# :-We can use Exception handling Method To save our programme from crashing
#
# Try-Except or Try-Except-finally Method
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# :-Try Clause and Except Clause means in programme the code which is potentially cause error is kept in try clause and the code that executes to happenes in programme is kept in except clause
