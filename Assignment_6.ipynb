# %% [raw]
# 1. What are escape characters, and how do you use them?
#
# :-IF we working with strings if there is a word which is double quote in between of string and when we run the code we get a error so the word which is in double quote has backslash
#
# Ex:text="This is my Sixth "Assignment" and i am Enjoing it" # You Will get Error
#
#    text="This is my Sixth \"Assignment"\ and i am Enjoing it" # we have use Escape character to avoid error
#
#
# 2. What do the escape characters n and t stand for?
#
# :-\n defines New Line And \t defines Tab
#
# 3. What is the way to include backslash characters in a string?
#
# :-Use syntex as mentiond
# text="This is my Sixth \"Assignment\" and i Am Enjoing it"
#
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the
# word Howl's not escaped a problem?
#
# :-The string "Howl's Moving Castle" is a correct value. beacause we have use starting and ending quotes
#
# 5. How do you write a string of newlines if you don't want to use the n character?
#
# :- We can Just Use \n before the word and you want the rest of the sentence to be start from next line it automatically translate to next line
#
# 6. What are the values of the given expressions?
#
# :-  'Hello, world!'[1]    :-'e'
#
#     'Hello, world!'[0:5]  :-'Hello'
#
#     'Hello, world!'[:5]   :-'Hello'
#
#     'Hello, world!'[3:]   :-'lo, world!'
#
# 7. What are the values of the following expressions?
#
# :-  'Hello'.upper()            :-'HELLO'
#
#     'Hello'.upper().isupper()  :-True
#
#     'Hello'.upper().lower()    :-'hello'
#
#
# 8. What are the values of the following expressions?
#
# :-'Remember, remember, the fifth of July.'.split()   :-['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
#
#   '-'.join('There can only one.'.split())            :-'There-can-only-one.'
#
#
# 9. What are the methods for right-justifying, left-justifying, and centering a string?
#
# :-orignal="My Name Is Milind And Join The FSDS BOOTCAMP"
#
# rjust:- '      My Name Is Milind And Join The FSDS BOOTCAMP'
#
# ljust:- 'My Name Is Milind And Join The FSDS BOOTCAMP      '
#
# center:-'   My Name Is Milind And Join The FSDS BOOTCAMP   '
#
#
# 10. What is the best way to remove whitespace characters from the start or end?
#
# :-We Can Use Strip() method
#
#  orignal="      My Name Is Milind And Join The FSDS BOOTCAMP     "
#
#  orignal.strip()
#
#  output:-'My Name Is Milind And Join The FSDS BOOTCAMP'
