# %% [raw]
# 1. What does an empty dictionary's code look like?
#
# :-To Create Empty Dictionary's Code Loke Like
#
#     d={}
#
# 2. What is the value of a dictionary value with the key "foo" and the value 42?
#
# :-d={"foo":42}
#
# output:-{'foo':42}
#
# 3. What is the most significant distinction between a dictionary and a list?
#
# :-list is ordered sequence of object and dictionary is unordered set of keys and values so in dictionary items are call by it's keys and in list it is call by position of items
#
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# :- we will get keyerror:'foo'
#
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.keys()?
#
# :-spam={'cat':300}
#
#   'cat' in spam
#
# output:-True
#
# 'cat' in spam.keys()
#
# output:- True
#
#
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.values()?
#
# :-spam={'cat':300}
#
#   'cat' in spam
#
# output:-True
#
# 'cat' in spam.values()
#
# output:- False
#
#
# 7. What is a shortcut for the following code?
# if 'color' not in spam:
# spam['color'] = 'black'
#
# :-spam={"Dog":51}
#   spam.setdefault('color','black')
#   spam
#
# output:-{'Dog':51,'color':'black'}
#
#
# 8. How do you "pretty print" dictionary values using which module and function?
#
# :-pprint.pprint()
#
# import pprint
#
# dict = [ {'Name': 'Anup', 'Age': '24', 'State': 'Mumbai'},
#   {'Name': 'Golu', 'Age': '51', 'State': 'Korea'},
#   {'Name': 'Anjan', 'Age': '42', 'State': 'Punjab'},
#   {'Name': 'Milind', 'Age': '15', 'State': 'Kolkata'}
# ]
#
#
# pprint.pprint(dict)
#
# output:-[{'Age': '24', 'Name': 'Anup', 'State': 'Mumbai'},
#          {'Age': '51', 'Name': 'Golu', 'State': 'Korea'},
#          {'Age': '42', 'Name': 'Anjan', 'State': 'Punjab'},
#          {'Age': '15', 'Name': 'Milind','State': 'Kolkata'}]
