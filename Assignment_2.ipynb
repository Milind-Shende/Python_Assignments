# %%
'''1.What are the two values of the Boolean data type? How do you write them?'''

The Two Value of the Boolean data Types are
1. True
2. False

And we can check them by
type()
ex:-
    type(True)
    <class 'bool'>
    type(False)
    <class 'bool'>
'''2. What are the three different types of Boolean operators?'''

The Three Different type of Boolean Operatores are
1.AND
2.OR
3.NOT

'''3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean
values for the operator and what it evaluate ).'''

#AND

True and True = True 
True and False = False
False and False = False
False and True = False

# OR

True or True = True
True or False =True
False or False = False
False or True = True

# NOT The NOT operator tell's Truth Value of its Operand i.e not Ture = False ,not False = True 

not True==False=True
not False<True=False
not False>True=True

'''4. What are the values of the following expressions?'''

1. (5 > 4) and (3 == 5) = False
2. not (5 > 4) = False
3. (5 > 4) or (3 == 5) = True
4. not ((5 > 4) or (3 == 5)) = False
5. (True and True) and (True == False) = False
6. (not False) or (not True) = True


'''5. What are the six comparison operators?'''

1.(<) Less Than
2.(>) Greater Than
3.(<=) Less Than Equal To
4.(>=) Greater Than Equal To
5.(==) Equal To
6.(!=) Not Equal To


'''7. Identify the three blocks in this code:'''

spam = 0 #Given Input
if spam == 10: #First It will Check whether if 0 is equal to 10 Condition is not  Satisfy So it will move to NEXT condition
    print('eggs')
if spam > 5:
    print('bacon')#second Condition also not satisfiy Bcoz if 0 is not greater than 5 it will move to next condition
else:  # and it will print Else condition
    print('ham')
    print('spam')
    print('spam')

'''8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
Greetings! if anything else is stored in spam.'''


spam=0

if spam==1:
    print('Hello')
elif spam==2:
    print('Howdy')
else:
    print('Greetings!')
    
    
'''9.If your programme is stuck in an endless loop, what keys you’ll press?'''

Key We Can Used When We are Stuck In An Endless Loop Is A Break Command

while True:
    if 5>2:
        print('Hello')
        break

Or Press CTRL+C        
        
'''10. How can you tell the difference between break and continue?'''

BREAK:-The Break statement terminates Endless Loop And falls out of the loop

AND

CONTINUE:-The Continue statement is used to skiip the current itration And Move To Next Itration 
    
    
'''11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?'''


Range(0):-Range(STARTS)
Range(0,10):-Range(STARTS,STOP)
Range(0,10,1):-Range(STARTS,STOP,STEPS)
    
    
'''12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
program that prints the numbers 1 to 10 using a while loop.'''


for i in range(1,11):
    print(i)

AND

i=1
while i<=10:
    print(i)
    i+=1
    
    
'''13. If you had a function named bacon() inside a module named spam, how would you call it after
importing spam?'''

By using dot notation

spam.bacon()
