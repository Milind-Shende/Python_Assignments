# %%
'''1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.'''

*:-(Expression)
'hello':-(Value)
-87.8:-(Value)
-:-(Expression)
/:-(Expression)
+:-(Expression)
6:-(Value)
    
'''2. What is the difference between string and variable?'''

String:-String Is the information which we store In Variable.
Ex(Name:-"Milo") In which "Milo" Is (String) In Which We Store In Variable (Name)
    &
Variable:-Variable Is used to Store Information.
Ex(Name:-"Milo") In which "Milo" Is (String) In Which We Store In Variable (Name)
    
'''3. Describe three different data types?'''  
Integer:-(Ex:-Integer(5))
Floating No.:-(Floating No.6.0)
Complex No.:-(Complex No.24+6j)

'''4. What is an expression made up of? What do all expressions do?'''

Expression Is Made Up Of different Combination of Operators to perform Operation to Get Some Value.
Ex:-(Expression:-Mul(*),Add(+),Sub(-),Div(/))
    
'''5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?'''

Expression Is Made Up Of different Combination of operator to perform Operation to Get Some Value
&
Statement Is nothing But Value Which We Print to get Output

Ex:-a=5
    b=5
    spam=a+b
    print(spam)

'''6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1'''

bacon = 22
a=bacon + 1
print(a)
output:-23
    
'''7. What should the values of the following two terms be?
'spam'+ 'spamspam',
'spam' * 3'''

Both will have same output
(spamspamspam)

'''8. Why is eggs a valid variable name while 100 is invalid?'''

Valid Variable Is Nothing but Which Starts With
( _ ,Lower Case Alphabet(a),Upper Case Alphabet(A)) _Milo or milo_Frind so eggs is valid variable

And It should Not Starts With Number So 100 Is invalid Number

'''9. What three functions can be used to get the integer, floating-point number, or string
version of a value?'''

int()
float()
str()

'''10. Why does this expression cause an error? How can you fix it?
'I have eaten' + 99 + 'burritos'.'''
 
we can concatenate string but Not a integer
And We Can Fix It.:- 'I have eaten' + ' 99 ' + 'burritos'
